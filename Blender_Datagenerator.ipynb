# %%
#Latin Hypercube Sampling

# %%
import bpy
import subprocess
import json
import os
import random
from pathlib import Path

# %% [markdown]
# ## Getting the position of the armature from Blender

# %% [markdown]
# This function
# - reaches out to the specified blender file
# - returns the position of the armature

# %%
def get_armature_from_blender(blend_file_path):
    blender_executable_path = '/Applications/Blender3.4.1.app/Contents/MacOS/Blender'     # Mac
    # blender_executable_path = ''     # Windows
    script_file_path = 'utils/get_armature.py'
    command = [
        blender_executable_path,
        '-b', blend_file_path,
        '-P', script_file_path,
        '--',
    ]
    
    result = subprocess.run(command, capture_output=True, text=True)
    output_lines = result.stdout.split('\n')
    json_data = ''
    recording = False
    for line in output_lines:
        if line == '---JSON_START---':
            recording = True
        elif line == '---JSON_END---':
            break
        elif recording:
            json_data += line

    try:
        if json_data:
            armature_data = json.loads(json_data)
            return armature_data
        else:
            print("No armature data was found.")
            return None
    except json.JSONDecodeError as e:
        print(f"Failed to decode JSON from Blender output: {e}")
        return None

# %% [markdown]
# ## Applying the Perturbation

# %% [markdown]
# This function...
# - changes the rig in a random way
# - based on the constraints it is given in armature_boundaries.json
# - the idle/base configuration is being taken from armature_data.json

# %%
def perturbate_armature_in_blender(blend_file_path):
    blender_executable_path = '/Applications/Blender3.4.1.app/Contents/MacOS/Blender' # Mac
    # blender_executable_path = '' # Windows    
    script_file_path = '/Users/leonpaletta/Coding/MT/root/render/utils/perturbate_armature.py'  
    path_of_idle_armature = 'idle_armature.json'
    
    command = [
        blender_executable_path,
        '-b', blend_file_path,
        '--python', script_file_path,
        '--', path_of_idle_armature
    ]
    subprocess.run(command)

# %% [markdown]
# ## Rendering the scene in Blender

# %%
def render_blend_file(blend_file_path, output_folder, out_file_name, running_number, current_rig_params):
    os.makedirs(output_folder, exist_ok=True)
    blender_executable_path = '/Applications/Blender3.4.1.app/Contents/MacOS/Blender' # Mac
    # blender_executable_path = '' # Windows
    output_file_path = os.path.join(output_folder, f"{running_number}_{out_file_name}")
    params_json_path = os.path.join(output_folder, 'rendering_rig_params.json')

    py_command = "import bpy; bpy.context.scene.render.resolution_x=512; bpy.context.scene.render.resolution_y=512; bpy.context.scene.render.resolution_percentage=100"

    command = [
        blender_executable_path,        # Path to the Blender executable
        '-b', blend_file_path,          # Specify the .blend file
        '--python-expr', py_command,    # Run the Python command to set resolution
        '-o', output_file_path,         # Set the output file path
        '-F', 'PNG',                    # Set the output format to PNG
        '-f', '1'                       # Render the first frame (change as needed)
    ]
    subprocess.run(command)    
    print(f"Render complete: {output_file_path}")

    if Path(params_json_path).exists():
        with open(params_json_path, 'r') as file:
            data = json.load(file)
    else:
        data = {}
    
    data[str(running_number)] = current_rig_params
    
    with open(params_json_path, 'w') as file:
        json.dump(data, file, indent=4)

# %% [markdown]
# # Applying the shit

# %% [markdown]
# When running the first time with a new character, first run this, so that the idle armature is being saved:

# %%
path_to_blender_file = '/Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend'
first_time = False


bones_data = get_armature_from_blender(path_to_blender_file)
print("The idle position of the relevant bones in the armature is: ")
print(bones_data)
if first_time:
    output_file='idle_armature.json'
    with open(output_file, 'w') as outfile:
        json.dump(bones_data, outfile, indent=4)
    print("Saved the idle armature to idle_armature.json")
# Out:
# The idle position of the relevant bones in the armature is:
# {'jaw_master': {'location': [0.07955741882324219, -7.746394634246826, 160.69256591796875], 'rotation': [1.0, 0.0, 0.0, 0.0]}, 'eyes': {'location': [0.07955741882324219, -33.89311218261719, 162.1348876953125], 'rotation': [1.0, 0.0, 0.0, 0.0]}, 'eye.R': {'location': [-3.5866665840148926, -33.89311218261719, 162.1348876953125], 'rotation': [1.0, 0.0, 0.0, 0.0]}, 'eye.L': {'location': [3.745781421661377, -33.89311218261719, 162.1348876953125], 'rotation': [1.0, 0.0, 0.0, 0.0]}}

# %%
perturbate_armature_in_blender(path_to_blender_file)
get_armature_from_blender(path_to_blender_file)
# Out:
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# {'jaw_master': {'location': [-1.3507120609283447,
#    -6.2061614990234375,
#    161.39935302734375],
#   'rotation': [1.0,
#    0.026017513126134872,
#    -0.0071640172973275185,
#    -0.0944049209356308]},
#  'eyes': {'location': [-0.806123673915863,
#    -33.98600769042969,
#    160.32020568847656],
#   'rotation': [1.0,
#    -8.419555342698004e-06,
#    -7.307767191377934e-06,
#    6.839448815298965e-06]},
#  'eye.R': {'location': [-5.05916690826416,
#    -33.93577194213867,
#    160.699462890625],
#   'rotation': [1.0,
#    -9.12790528673213e-06,
#    3.6711014672619058e-06,
#    5.0047756303683855e-06]},
#  'eye.L': {'location': [2.0793166160583496,
#    -33.632049560546875,
#    159.5586700439453],
#   'rotation': [1.0,
#    2.7371345368010225e-06,
#    -9.98590167000657e-06,
#    9.8491027529235e-06]}}

# %% [markdown]
# # Data Generator
# Creates samples...
# - in the predefined range specified in armature_boundaries.json
# - takes as idle position the information from idle_armature.json
# - takes into consideration all the bones specified in relevant_armature.json

# %%
n_samples = 64

# %%
# dont change anything, just run this first and change the name to 'idle.png', which will then be the reference picture
rig_params = get_armature_from_blender(path_to_blender_file)
render_blend_file(blend_file_path = path_to_blender_file, output_folder = 'output/', out_file_name = 'rendis', running_number = str(i), current_rig_params = rig_params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # dont change anything, just run this first and change the name to 'idle.png', which will then be the reference picture
#       2 rig_params = get_armature_from_blender(path_to_blender_file)
# ----> 3 render_blend_file(blend_file_path = path_to_blender_file, output_folder = 'output/', out_file_name = 'rendis', running_number = str(i), current_rig_params = rig_params)
#
# NameError: name 'i' is not defined

# %%
for i in range(1, n_samples): 
    perturbate_armature_in_blender(path_to_blender_file)
    rig_params = get_armature_from_blender(path_to_blender_file)
    render_blend_file(blend_file_path = path_to_blender_file, output_folder = 'output/', out_file_name = 'rendis', running_number = str(i), current_rig_params = rig_params)
# Out:
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.61 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.61 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.61 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.11 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.61 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.61 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.61 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.62 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.73 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.76 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.78 | Rendering 64 / 64 samples
# Saved: 'output/1_rendis0001.png'
#  Time: 00:02.90 (Saving: 00:00.11)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/1_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.10 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.56 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.56 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.56 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.57 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.67 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.70 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.72 | Rendering 64 / 64 samples
# Saved: 'output/2_rendis0001.png'
#  Time: 00:02.83 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/2_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.60 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.60 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.11 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.58 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.58 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.58 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.59 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.69 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.73 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.75 | Rendering 64 / 64 samples
# Saved: 'output/3_rendis0001.png'
#  Time: 00:02.86 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/3_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.60 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.60 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.60 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.53 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.53 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.53 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.54 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.63 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.67 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.69 | Rendering 64 / 64 samples
# Saved: 'output/4_rendis0001.png'
#  Time: 00:02.80 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/4_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.08 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.49 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.49 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.49 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.49 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.59 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.62 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.64 | Rendering 64 / 64 samples
# Saved: 'output/5_rendis0001.png'
#  Time: 00:02.75 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/5_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.60 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.60 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.60 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.50 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.50 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.50 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.51 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.60 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.64 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.66 | Rendering 64 / 64 samples
# Saved: 'output/6_rendis0001.png'
#  Time: 00:02.77 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/6_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.60 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.60 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.60 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.12 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.56 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.56 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.56 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.57 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.67 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.70 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.72 | Rendering 64 / 64 samples
# Saved: 'output/7_rendis0001.png'
#  Time: 00:02.83 (Saving: 00:00.11)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/7_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.61 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.61 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.61 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.11 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.53 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.53 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.53 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.54 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.63 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.67 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.69 | Rendering 64 / 64 samples
# Saved: 'output/8_rendis0001.png'
#  Time: 00:02.80 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/8_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.63 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.63 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.63 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.15 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.66 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.66 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.66 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.66 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.76 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.80 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.81 | Rendering 64 / 64 samples
# Saved: 'output/9_rendis0001.png'
#  Time: 00:02.93 (Saving: 00:00.11)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/9_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.62 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.62 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.62 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.13 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.60 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.60 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.60 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.60 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.70 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.74 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.76 | Rendering 64 / 64 samples
# Saved: 'output/10_rendis0001.png'
#  Time: 00:02.87 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/10_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.62 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.62 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.62 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.13 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.55 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.55 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.55 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.55 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.65 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.69 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.71 | Rendering 64 / 64 samples
# Saved: 'output/11_rendis0001.png'
#  Time: 00:02.82 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/11_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.50 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.50 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.50 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.51 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.61 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.65 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.67 | Rendering 64 / 64 samples
# Saved: 'output/12_rendis0001.png'
#  Time: 00:02.79 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/12_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.61 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.61 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.61 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.10 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.54 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.54 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.54 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.54 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.64 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.67 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.69 | Rendering 64 / 64 samples
# Saved: 'output/13_rendis0001.png'
#  Time: 00:02.81 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/13_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.60 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.60 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.60 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.50 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.50 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.50 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.51 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.60 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.64 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.66 | Rendering 64 / 64 samples
# Saved: 'output/14_rendis0001.png'
#  Time: 00:02.77 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/14_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.58 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.58 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.58 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.07 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.47 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.47 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.47 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.48 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.57 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.60 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.62 | Rendering 64 / 64 samples
# Saved: 'output/15_rendis0001.png'
#  Time: 00:02.73 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/15_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.08 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.49 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.49 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.49 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.50 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.59 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.63 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.65 | Rendering 64 / 64 samples
# Saved: 'output/16_rendis0001.png'
#  Time: 00:02.76 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/16_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.60 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.60 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.60 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.08 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.48 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.48 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.48 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.49 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.59 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.63 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.64 | Rendering 64 / 64 samples
# Saved: 'output/17_rendis0001.png'
#  Time: 00:02.76 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/17_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.08 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.47 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.47 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.47 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.48 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.57 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.61 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.63 | Rendering 64 / 64 samples
# Saved: 'output/18_rendis0001.png'
#  Time: 00:02.74 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/18_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.08 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.47 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.47 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.48 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.48 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.58 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.62 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.63 | Rendering 64 / 64 samples
# Saved: 'output/19_rendis0001.png'
#  Time: 00:02.75 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/19_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.58 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.58 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.58 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.07 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.50 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.50 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.50 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.51 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.60 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.64 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.66 | Rendering 64 / 64 samples
# Saved: 'output/20_rendis0001.png'
#  Time: 00:02.77 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/20_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.61 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.61 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.61 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.12 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.54 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.54 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.54 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.55 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.64 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.68 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.70 | Rendering 64 / 64 samples
# Saved: 'output/21_rendis0001.png'
#  Time: 00:02.81 (Saving: 00:00.11)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/21_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.60 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.60 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.60 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.11 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.52 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.52 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.52 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.53 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.62 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.66 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.68 | Rendering 64 / 64 samples
# Saved: 'output/22_rendis0001.png'
#  Time: 00:02.79 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/22_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.60 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.60 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.60 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.10 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.51 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.51 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.51 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.51 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.61 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.65 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.67 | Rendering 64 / 64 samples
# Saved: 'output/23_rendis0001.png'
#  Time: 00:02.78 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/23_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.58 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.58 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.58 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.08 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.48 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.48 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.48 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.49 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.58 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.62 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.64 | Rendering 64 / 64 samples
# Saved: 'output/24_rendis0001.png'
#  Time: 00:02.75 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/24_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.08 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.48 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.48 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.48 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.49 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.58 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.62 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.64 | Rendering 64 / 64 samples
# Saved: 'output/25_rendis0001.png'
#  Time: 00:02.75 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/25_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.10 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.55 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.55 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.55 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.56 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.65 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.69 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.71 | Rendering 64 / 64 samples
# Saved: 'output/26_rendis0001.png'
#  Time: 00:02.82 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/26_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.10 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.56 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.56 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.56 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.56 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.66 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.70 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.72 | Rendering 64 / 64 samples
# Saved: 'output/27_rendis0001.png'
#  Time: 00:02.83 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/27_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.60 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.60 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.60 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.10 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.51 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.51 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.51 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.52 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.62 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.65 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.67 | Rendering 64 / 64 samples
# Saved: 'output/28_rendis0001.png'
#  Time: 00:02.78 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/28_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.50 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.50 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.50 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.50 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.60 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.64 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.66 | Rendering 64 / 64 samples
# Saved: 'output/29_rendis0001.png'
#  Time: 00:02.77 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/29_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.07 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.48 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.48 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.48 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.49 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.58 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.62 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.64 | Rendering 64 / 64 samples
# Saved: 'output/30_rendis0001.png'
#  Time: 00:02.75 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/30_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.58 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.58 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.58 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.07 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.49 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.49 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.49 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.49 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.59 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.63 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.65 | Rendering 64 / 64 samples
# Saved: 'output/31_rendis0001.png'
#  Time: 00:02.76 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/31_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.08 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.50 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.50 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.50 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.51 | Rendering 1 / 64 samples
# ...
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.60 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.10 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.52 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.52 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.52 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.53 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.62 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.66 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.68 | Rendering 64 / 64 samples
# Saved: 'output/53_rendis0001.png'
#  Time: 00:02.79 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/53_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.08 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.48 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.48 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.48 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.48 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.58 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.61 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.63 | Rendering 64 / 64 samples
# Saved: 'output/54_rendis0001.png'
#  Time: 00:02.74 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/54_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.60 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.60 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.60 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.49 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.49 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.49 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.50 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.59 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.63 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.64 | Rendering 64 / 64 samples
# Saved: 'output/55_rendis0001.png'
#  Time: 00:02.76 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/55_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.58 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.58 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.58 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.49 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.49 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.49 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.50 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.59 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.62 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.64 | Rendering 64 / 64 samples
# Saved: 'output/56_rendis0001.png'
#  Time: 00:02.75 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/56_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.08 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.48 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.48 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.48 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.49 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.58 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.61 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.63 | Rendering 64 / 64 samples
# Saved: 'output/57_rendis0001.png'
#  Time: 00:02.74 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/57_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.62 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.62 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.62 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.12 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.53 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.53 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.53 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.54 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.64 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.68 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.69 | Rendering 64 / 64 samples
# Saved: 'output/58_rendis0001.png'
#  Time: 00:02.81 (Saving: 00:00.11)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/58_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.51 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.51 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.51 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.52 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.61 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.65 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.67 | Rendering 64 / 64 samples
# Saved: 'output/59_rendis0001.png'
#  Time: 00:02.78 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/59_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.51 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.51 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.51 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.52 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.61 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.64 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.66 | Rendering 64 / 64 samples
# Saved: 'output/60_rendis0001.png'
#  Time: 00:02.78 (Saving: 00:00.11)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/60_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.60 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.60 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.60 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.10 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.53 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.53 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.53 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.54 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.63 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.67 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.69 | Rendering 64 / 64 samples
# Saved: 'output/61_rendis0001.png'
#  Time: 00:02.80 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/61_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.51 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.51 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.51 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.51 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.61 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.64 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.66 | Rendering 64 / 64 samples
# Saved: 'output/62_rendis0001.png'
#  Time: 00:02.78 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/62_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
#
# Blender quit
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/characters/blender_base/ulf.blend
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.55M (Peak 88.68M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.56M (Peak 88.68M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.75M (Peak 135.59M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.07M (Peak 632.80M) | Time:00:02.49 | Syncing rig
# Fra:1 Mem:378.08M (Peak 632.80M) | Time:00:02.49 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.16M (Peak 632.80M) | Time:00:02.49 | Syncing metarig
# Fra:1 Mem:377.64M (Peak 632.80M) | Time:00:02.49 | Rendering 1 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.59 | Rendering 26 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.62 | Rendering 51 / 64 samples
# Fra:1 Mem:376.00M (Peak 632.80M) | Time:00:02.64 | Rendering 64 / 64 samples
# Saved: 'output/63_rendis0001.png'
#  Time: 00:02.75 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: output/63_rendis
