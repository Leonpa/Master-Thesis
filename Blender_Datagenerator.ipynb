# %%
import bpy
import subprocess
import json
import os
import random
from pathlib import Path

# %% [markdown]
# ## Getting the position of the armature from Blender

# %% [markdown]
# This function
# - reaches out to the specified blender file
# - returns the position of the armature

# %%
def get_armature_from_blender(blend_file_path):
    blender_executable_path = '/Applications/Blender3.4.1.app/Contents/MacOS/Blender'     # Mac
    # blender_executable_path = ''     # Windows
    script_file_path = 'utils/get_armature.py'
    command = [
        blender_executable_path,
        '-b', blend_file_path,
        '-P', script_file_path,
        '--',
    ]    
    result = subprocess.run(command, capture_output=True, text=True)
    # print(result)
    output_lines = result.stdout.split('\n')
    json_data = ''
    recording = False
    for line in output_lines:
        if line == '---JSON_START---':
            recording = True
        elif line == '---JSON_END---':
            break
        elif recording:
            json_data += line

    try:
        if json_data:
            armature_data = json.loads(json_data)
            return armature_data
        else:
            print("No armature data was found.")
            return None
    except json.JSONDecodeError as e:
        print(f"Failed to decode JSON from Blender output: {e}")
        return None

# %% [markdown]
# ## Applying the Perturbation

# %% [markdown]
# This function...
# - changes the rig in a random way
# - based on the constraints it is given in armature_boundaries.json
# - the idle/base configuration is being taken from armature_data.json

# %%
def perturbate_armature_in_blender(blend_file_path):
    blender_executable_path = '/Applications/Blender3.4.1.app/Contents/MacOS/Blender' # Mac
    # blender_executable_path = '' # Windows    
    script_file_path = 'utils/perturbate_armature.py'  
    path_of_idle_armature = 'idle_armature.json'
    
    command = [
        blender_executable_path,
        '-b', blend_file_path,
        '--python', script_file_path,
        '--', path_of_idle_armature
    ]
    result = subprocess.run(command)
    print(result)

# %% [markdown]
# ## Rendering the scene in Blender

# %%
def render_blend_file(blend_file_path, output_folder, out_file_name, running_number, current_rig_params):
    os.makedirs(output_folder, exist_ok=True)
    blender_executable_path = '/Applications/Blender3.4.1.app/Contents/MacOS/Blender' # Mac
    # blender_executable_path = '' # Windows
    output_file_path = os.path.join(output_folder, f"{running_number}_{out_file_name}")
    params_json_path = os.path.join(output_folder, 'rendering_rig_params.json')

    py_command = "import bpy; bpy.context.scene.render.resolution_x=512; bpy.context.scene.render.resolution_y=512; bpy.context.scene.render.resolution_percentage=100"

    command = [
        blender_executable_path,        # Path to the Blender executable
        '-b', blend_file_path,          # Specify the .blend file
        '--python-expr', py_command,    # Run the Python command to set resolution
        '-o', output_file_path,         # Set the output file path
        '-F', 'PNG',                    # Set the output format to PNG
        '-f', '1'                       # Render the first frame (change as needed)
    ]
    subprocess.run(command)    
    print(f"Render complete: {output_file_path}")

    if Path(params_json_path).exists():
        with open(params_json_path, 'r') as file:
            data = json.load(file)
    else:
        data = {}
    
    data[str(running_number)] = current_rig_params
    
    with open(params_json_path, 'w') as file:
        json.dump(data, file, indent=4)

# %% [markdown]
# # Creating the Idle

# %% [markdown]
# When running the first time with a new character, first run this, so that the idle armature is being saved:

# %%
first_time = False
path_to_blender_file = '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend'

idle_rig_params = get_armature_from_blender(path_to_blender_file)
print("The idle position of the relevant bones in the armature is: ")
print(idle_rig_params)
if first_time:
    output_file='data/armature_configuration/idle_armature.json'
    with open(output_file, 'w') as outfile:
        json.dump(idle_rig_params, outfile, indent=4)
    print("Saved the idle armature to idle_armature.json")
# Out:
# The idle position of the relevant bones in the armature is:
# {'jaw_master': {'location': [0.07955741882324219, -7.746394634246826, 160.69256591796875], 'rotation': [1.0, 0.0, 0.0, 0.0]}, 'cheek.B.R.001': {'location': [-5.149785041809082, -11.945501327514648, 157.17555236816406], 'rotation': [1.0, 0.0, 0.0, 0.0]}, 'cheek.T.R.001': {'location': [-3.9348154067993164, -13.465989112854004, 159.122314453125], 'rotation': [1.0, 0.0, 0.0, 0.0]}, 'lips.R': {'location': [-2.4214324951171875, -13.92071533203125, 155.97479248046875], 'rotation': [1.0, 0.0, 0.0, 0.0]}, 'brow.T.R.003': {'location': [-1.4480360746383667, -14.290176391601562, 163.5772247314453], 'rotation': [1.0, 0.0, 0.0, 0.0]}, 'lid.B.R.002': {'location': [-3.8495543003082275, -13.380725860595703, 161.36753845214844], 'rotation': [1.0, 0.0, 0.0, 0.0]}, 'cheek.B.L.001': {'location': [5.308899879455566, -11.945501327514648, 157.17555236816406], 'rotation': [1.0, 0.0, 0.0, 0.0]}, 'cheek.T.L.001': {'location': [4.093930721282959, -13.465989112854004, 159.12232971191406], 'rotation': [1.0, 0.0, 0.0, 0.0]}, 'lips.L': {'location': [2.580547332763672, -13.92071533203125, 155.97479248046875], 'rotation': [1.0, 0.0, 0.0, 0.0]}, 'brow.T.L.003': {'location': [1.607150673866272, -14.290176391601562, 163.5772247314453], 'rotation': [1.0, 0.0, 0.0, 0.0]}, 'lid.B.L.002': {'location': [4.008669376373291, -13.380725860595703, 161.3675537109375], 'rotation': [1.0, 0.0, 0.0, 0.0]}}

# %% [markdown]
# Then let's render the idle picture and create

# %%
print(idle_rig_params)

# %%
# path_to_blender_file = '/Users/leonpaletta/Coding/MT/root/data/blender_characters/sad_ulf.blend'
# render_blend_file(blend_file_path = path_to_blender_file, output_folder = 'data/render_trainset', out_file_name = 'sad.png', running_number = 'idle_params', current_rig_params = idle_rig_params)

# %% [markdown]
# ## Rendering Results of single Characters

# %%
path_to_blender_file = '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend'
out_name = 'neutral_ulf'
render_blend_file(blend_file_path = path_to_blender_file, output_folder = 'data/output_generation', out_file_name = out_name, running_number = '', current_rig_params = None)
# Out:
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.62 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.62 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.62 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.13 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.63 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.63 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.63 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.64 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.74 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.78 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.80 | Rendering 64 / 64 samples
# Saved: 'data/output_generation/_neutral_ulf0001.png'
#  Time: 00:02.91 (Saving: 00:00.11)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/output_generation/_neutral_ulf

# %% [markdown]
# ### Data Generator
# Creates samples...
# - in the predefined range specified in armature_boundaries.json
# - takes as idle position the information from idle_armature.json
# - takes into consideration all the bones specified in relevant_armature.json

# %%
n_samples = 200

# %%
for i in range(1, n_samples): 
    perturbate_armature_in_blender(path_to_blender_file)
    current_rig_params = get_armature_from_blender(path_to_blender_file)

    diff_rig_params = {}
    for part, params in current_rig_params.items():
        idle_part_params = idle_rig_params.get(part, {})
        diff_location = [curr - idle for curr, idle in zip(params['location'], idle_part_params.get('location', [0, 0, 0]))]
        diff_rotation = [curr - idle for curr, idle in zip(params['rotation'], idle_part_params.get('rotation', [1, 0, 0, 0]))]
        diff_rig_params[part] = {'location': diff_location, 'rotation': diff_rotation}

    
    render_blend_file(blend_file_path = path_to_blender_file, output_folder = 'data/render_trainset', out_file_name = 'rendis', running_number = str(i), current_rig_params = diff_rig_params)
# Out:
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.60 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.60 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.60 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.10 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.65 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.65 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.65 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.65 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.81 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.86 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.89 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/1_rendis0001.png'
#  Time: 00:03.00 (Saving: 00:00.11)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/1_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.54 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.54 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.54 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.55 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.65 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.68 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.70 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/2_rendis0001.png'
#  Time: 00:02.81 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/2_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.08 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.50 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.50 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.50 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.50 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.60 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.64 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.65 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/3_rendis0001.png'
#  Time: 00:02.78 (Saving: 00:00.11)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/3_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.60 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.60 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.60 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.10 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.51 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.51 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.51 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.52 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.61 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.65 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.66 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/4_rendis0001.png'
#  Time: 00:02.77 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/4_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.54 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.54 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.54 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.55 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.64 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.68 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.69 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/5_rendis0001.png'
#  Time: 00:02.80 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/5_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.60 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.60 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.60 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.52 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.52 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.52 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.53 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.63 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.67 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.68 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/6_rendis0001.png'
#  Time: 00:02.80 (Saving: 00:00.11)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/6_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.60 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.60 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.60 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.50 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.50 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.50 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.51 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.61 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.64 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.66 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/7_rendis0001.png'
#  Time: 00:02.77 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/7_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.60 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.60 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.60 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.54 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.54 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.54 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.55 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.65 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.68 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.70 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/8_rendis0001.png'
#  Time: 00:02.81 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/8_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.52 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.52 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.52 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.53 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.63 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.66 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.68 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/9_rendis0001.png'
#  Time: 00:02.79 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/9_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.51 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.51 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.51 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.52 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.61 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.65 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.66 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/10_rendis0001.png'
#  Time: 00:02.77 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/10_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.08 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.52 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.52 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.52 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.53 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.63 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.66 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.68 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/11_rendis0001.png'
#  Time: 00:02.79 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/11_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.61 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.61 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.61 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.11 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.54 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.54 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.54 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.54 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.64 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.67 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.69 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/12_rendis0001.png'
#  Time: 00:02.80 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/12_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.08 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.52 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.52 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.52 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.53 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.63 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.66 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.68 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/13_rendis0001.png'
#  Time: 00:02.79 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/13_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.49 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.49 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.49 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.50 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.59 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.63 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.64 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/14_rendis0001.png'
#  Time: 00:02.76 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/14_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.08 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.48 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.48 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.48 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.49 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.59 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.62 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.64 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/15_rendis0001.png'
#  Time: 00:02.75 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/15_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.53 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.53 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.53 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.53 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.63 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.67 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.68 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/16_rendis0001.png'
#  Time: 00:02.79 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/16_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.48 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.48 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.48 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.49 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.59 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.62 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.64 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/17_rendis0001.png'
#  Time: 00:02.75 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/17_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.51 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.51 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.51 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.52 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.61 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.64 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.66 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/18_rendis0001.png'
#  Time: 00:02.78 (Saving: 00:00.11)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/18_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.52 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.52 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.52 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.53 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.62 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.65 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.67 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/19_rendis0001.png'
#  Time: 00:02.79 (Saving: 00:00.11)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/19_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.08 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.49 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.49 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.49 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.50 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.60 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.63 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.65 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/20_rendis0001.png'
#  Time: 00:02.76 (Saving: 00:00.11)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/20_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.55 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.55 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.55 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.56 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.65 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.68 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.70 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/21_rendis0001.png'
#  Time: 00:02.81 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/21_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.50 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.50 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.50 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.51 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.60 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.63 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.65 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/22_rendis0001.png'
#  Time: 00:02.76 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/22_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.07 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.47 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.47 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.47 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.48 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.57 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.61 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.62 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/23_rendis0001.png'
#  Time: 00:02.73 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/23_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.60 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.60 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.60 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.50 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.50 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.51 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.51 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.61 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.64 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.66 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/24_rendis0001.png'
#  Time: 00:02.78 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/24_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.48 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.48 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.48 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.49 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.59 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.63 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.64 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/25_rendis0001.png'
#  Time: 00:02.75 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/25_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.58 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.58 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.58 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.08 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.56 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.56 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.56 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.57 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.66 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.70 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.71 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/26_rendis0001.png'
#  Time: 00:02.83 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/26_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.08 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.51 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.51 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.51 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.51 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.61 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.65 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.67 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/27_rendis0001.png'
# ...
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.60 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.60 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.60 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.09 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.50 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.50 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.50 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.51 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.61 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.65 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.66 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/191_rendis0001.png'
#  Time: 00:02.78 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/191_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.08 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.48 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.48 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.48 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.49 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.59 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.62 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.64 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/192_rendis0001.png'
#  Time: 00:02.75 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/192_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.58 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.58 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.58 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.08 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.48 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.48 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.48 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.49 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.58 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.62 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.63 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/193_rendis0001.png'
#  Time: 00:02.75 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/193_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.58 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.58 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.58 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.07 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.47 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.47 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.47 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.47 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.57 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.60 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.62 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/194_rendis0001.png'
#  Time: 00:02.73 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/194_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.61 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.61 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.61 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.10 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.55 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.55 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.55 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.55 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.65 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.68 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.70 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/195_rendis0001.png'
#  Time: 00:02.81 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/195_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.58 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.58 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.58 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.07 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.47 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.47 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.47 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.48 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.58 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.61 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.63 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/196_rendis0001.png'
#  Time: 00:02.74 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/196_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.59 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.59 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.08 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.48 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.48 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.48 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.48 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.57 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.61 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.62 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/197_rendis0001.png'
#  Time: 00:02.74 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/197_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.58 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.58 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.58 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.07 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.47 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.47 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.47 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.48 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.58 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.61 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.63 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/198_rendis0001.png'
#  Time: 00:02.74 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/198_rendis
# Reloading external rigs...
# Reloading external metarigs...
# Info: Saved "ulf.blend"
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
#
# Blender quit
# CompletedProcess(args=['/Applications/Blender3.4.1.app/Contents/MacOS/Blender', '-b', '/Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend', '--python', 'utils/perturbate_armature.py', '--', 'idle_armature.json'], returncode=0)
# Blender 3.4.1 (hash 55485cb379f7 built 2022-12-20 00:48:52)
# Read prefs: /Users/leonpaletta/Library/Application Support/Blender/3.4/config/userpref.blend
# Read blend: /Users/leonpaletta/Coding/MT/root/data/blender_characters/ulf.blend
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.58 | Syncing Light
# Fra:1 Mem:87.56M (Peak 88.69M) | Time:00:00.58 | Syncing Camera
# Fra:1 Mem:87.57M (Peak 88.69M) | Time:00:00.58 | Syncing Ch22_Hair
# Fra:1 Mem:120.76M (Peak 135.60M) | Time:00:01.08 | Syncing Ch22_Body
# Fra:1 Mem:378.08M (Peak 632.81M) | Time:00:02.48 | Syncing rig
# Fra:1 Mem:378.09M (Peak 632.81M) | Time:00:02.48 | Syncing Ch22_Eyelashes
# Fra:1 Mem:378.17M (Peak 632.81M) | Time:00:02.48 | Syncing metarig
# Fra:1 Mem:377.65M (Peak 632.81M) | Time:00:02.49 | Rendering 1 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.59 | Rendering 26 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.62 | Rendering 51 / 64 samples
# Fra:1 Mem:376.01M (Peak 632.81M) | Time:00:02.64 | Rendering 64 / 64 samples
# Saved: 'data/render_trainset/199_rendis0001.png'
#  Time: 00:02.75 (Saving: 00:00.10)
#
# Reloading external rigs...
# Reloading external metarigs...
#
# Blender quit
# Render complete: data/render_trainset/199_rendis
